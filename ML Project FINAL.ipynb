# %%
pip install bing-image-downloader

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive
# Out:
# /content/drive

# %%
cd /content/drive/My Drive/smartknower/trial project
# Out:
# /content/drive/My Drive/smartknower/trial project

# %%
mkdir pics

# %%
from bing_image_downloader import downloader
downloader.download('cars',limit = 20,output_dir = 'pics')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.ytimg.com/vi/0WeQngGB2wY/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.ytimg.com/vi/DRu-BC9pqWw/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.ytimg.com/vi/gTKiau_ic9Q/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.ytimg.com/vi/pPfcconDJeg/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.ytimg.com/vi/TObBn68uRSA/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i.ytimg.com/vi/uFf1j4c70s8/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://i.ytimg.com/vi/kEZhvxOmtD8/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://i.ytimg.com/vi/3D9UiyddtDM/maxresdefault.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download('bicycle',limit = 20,output_dir='pics')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 20 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Left_side_of_Flying_Pigeon.jpg/1200px-Left_side_of_Flying_Pigeon.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Left_side_of_Flying_Pigeon.jpg/1200px-Left_side_of_Flying_Pigeon.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/4/41/Left_side_of_Flying_Pigeon.jpg/1200px-Left_side_of_Flying_Pigeon.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/3/37/Danish_bicycle_female.jpg/1200px-Danish_bicycle_female.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Moyer_Cycles_I.jpg/1200px-Moyer_Cycles_I.jpg
# ...

# %%
import cv2
import matplotlib.pyplot as plt
path = '/content/drive/My Drive/smartknower/trial project/pics/bicycle/Image_10.jpg'

i = cv2.imread(path)
i = cv2.cvtColor(i,cv2.COLOR_BGR2RGB)
plt.imshow(i)

# %%
import os
import cv2
path = '/content/drive/My Drive/smartknower/trial project/pics/bicycle'
for filename in os.listdir(path):
  i = cv2.imread(os.path.join(path,filename))
  print(i.shape)
# Out:
# (900, 1200, 3)
# (720, 1280, 3)
# (1005, 1508, 3)
# (739, 1200, 3)
# (720, 1280, 3)
# (1800, 1200, 3)
# (776, 1200, 3)
# (1750, 2100, 3)
# (900, 1200, 3)
# (724, 1200, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (768, 1024, 3)
# (720, 1280, 3)
# (900, 1200, 3)
# (720, 1280, 3)
# (900, 1200, 3)
# (1005, 1508, 3)
# (1200, 1200, 3)

# %%
path = '/content/drive/My Drive/smartknower/trial project/pics/cars'
for filename in os.listdir(path):
  i = cv2.imread(os.path.join(path,filename))
  print(i.shape)
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (360, 480, 3)
# (720, 1280, 3)

# %%
import numpy as np
from skimage.io import imread
from skimage.transform import resize

# %%
target = []
images = []
flat_data = []

# %%
path = '/content/drive/My Drive/smartknower/trial project/pics/'
for dirpath,dirnames,filenames in os.walk(path):
  for filename in filenames:
    category = dirpath.split('/')[-1]
    target.append(category)
    img = imread(f'{path}{category}/{filename}')
    img_resized = resize(img,(50,50,3))
    flat_data.append(img_resized.flatten())
    images.append(img_resized)

flat_data = np.array(flat_data)
images = np.array(images)
target = np.array(target)

print(target.size)
print(flat_data.shape)
print(images.shape)
print(target)
# Out:
# 41
# (41, 7500)
# (41, 50, 50, 3)
# ['cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars'
#  'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars' 'cars'
#  'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle'
#  'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle'
#  'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle' 'bicycle']

# %%
import pandas as pd
df = pd.DataFrame(flat_data)
df['Target'] = target
df.head()
# Out:
#           0         1         2         3  ...      7497      7498      7499  Target
# 0  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000    cars
# 1  0.789412  0.572549  0.666667  0.811765  ...  0.544275  0.000000  0.094118    cars
# 2  0.376471  0.721569  0.968627  0.372549  ...  0.529412  0.026627  0.065490    cars
# 3  0.450980  0.407020  0.330235  0.513608  ...  0.383490  0.367451  0.337255    cars
# 4  0.581569  0.003922  0.007843  0.697647  ...  0.278431  0.290196  0.309804    cars
#
# [5 rows x 7501 columns]

# %%
x = flat_data
x
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.78941176, 0.57254902, 0.66666667, ..., 0.54427451, 0.        ,
#         0.09411765],
#        [0.37647059, 0.72156863, 0.96862745, ..., 0.52941176, 0.02662745,
#         0.0654902 ],
#        ...,
#        [0.7       , 0.68823529, 0.68235294, ..., 0.66470588, 0.6627451 ,
#         0.6745098 ],
#        [0.85490196, 0.8745098 , 0.88627451, ..., 0.41568627, 0.70980392,
#         0.95117647],
#        [1.        , 1.        , 1.        , ..., 1.        , 1.        ,
#         1.        ]])

# %%
y = df.Target
y
# Out:
# 0        cars
# 1        cars
# 2        cars
# 3        cars
# 4        cars
# 5        cars
# 6        cars
# 7        cars
# 8        cars
# 9        cars
# 10       cars
# 11       cars
# 12       cars
# 13       cars
# 14       cars
# 15       cars
# 16       cars
# 17       cars
# 18       cars
# 19       cars
# 20    bicycle
# 21    bicycle
# 22    bicycle
# 23    bicycle
# 24    bicycle
# 25    bicycle
# 26    bicycle
# 27    bicycle
# 28    bicycle
# 29    bicycle
# 30    bicycle
# 31    bicycle
# 32    bicycle
# 33    bicycle
# 34    bicycle
# 35    bicycle
# 36    bicycle
# 37    bicycle
# 38    bicycle
# 39    bicycle
# 40    bicycle
# Name: Target, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (30, 7500)
# (30,)
# (11, 7500)
# (11,)

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array(['cars', 'cars', 'cars', 'cars', 'cars', 'bicycle', 'bicycle',
#        'bicycle', 'bicycle', 'cars', 'bicycle'], dtype=object)

# %%
y_test
# Out:
# 1        cars
# 15       cars
# 13       cars
# 8        cars
# 33    bicycle
# 40    bicycle
# 23    bicycle
# 24    bicycle
# 11       cars
# 9        cars
# 36    bicycle
# Name: Target, dtype: object

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8181818181818182

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[4, 1],
#        [1, 5]])

# %%
var = 1
while var ==1:
  print("enter png or jpg pic link of car or bicycle")
  path = input()
  img = imread(path)

  test_flat=[]
  imgas=[]
  img_resize = resize(img,(50,50,3))
  test_flat.append(img_resize.flatten())
  imgas.append(img_resize)

  output=model.predict(test_flat)
  print(output)
  print("try another pic press 1\n else enter 0")
  var = int(input())
# Out:
# enter png or jpg pic link of car or bicycle
# https://www.bicycleretailer.com/sites/default/files/images/article/08_S22_WHITE%20800.jpg
# ['bicycle']
# try another pic press 1
#  else enter 0
# 1
# enter png or jpg pic link of car or bicycle
# https://s3.caradvice.com.au/wp-content/uploads/2017/06/2017-Skoda-Octavia-110TSI-Wagon-DSG-24.jpg
# ['cars']
# try another pic press 1
#  else enter 0
# 0
